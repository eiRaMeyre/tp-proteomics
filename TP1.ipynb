# %%
# %matplotlib nbagg
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import norm

# %%
fig, ax = plt.subplots()
x = np.linspace(norm.ppf(0.01),
                norm.ppf(0.99), 100)

ax.plot(x, norm.pdf(x),
       'r-', lw=5, alpha=0.6)

ax.plot(x, np.full(len(x), 0.2),
       'b-', lw=1)

fig.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
from xml.etree.ElementTree import parse, dump
# Parse the E.Coli proteome XML Document
tree = parse('MADP_TP1/tp-proteomics/data/uniprot-proteome_UP000000625.xml')
root = tree.getroot()
ns = '{http://uniprot.org/uniprot}' # MANDATORY PREFIX FOR ANY SEARCH within document
# Store all entries aka proteins in a list of xml nodes
proteins = root.findall(ns + 'entry')
# Display the xml subtree of the first protein 
dump(proteins[0])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-16-d42a4dffe9be> in <module>
#       1 from xml.etree.ElementTree import parse, dump
#       2 # Parse the E.Coli proteome XML Document
# ----> 3 tree = parse('MADP_TP1/tp-proteomics/data/uniprot-proteome_UP000000625.xml')
#       4 root = tree.getroot()
#       5 ns = '{http://uniprot.org/uniprot}' # MANDATORY PREFIX FOR ANY SEARCH within document
#
# /usr/lib/python3.8/xml/etree/ElementTree.py in parse(source, parser)
#    1200     """
#    1201     tree = ElementTree()
# -> 1202     tree.parse(source, parser)
#    1203     return tree
#    1204
#
# /usr/lib/python3.8/xml/etree/ElementTree.py in parse(self, source, parser)
#     582         close_source = False
#     583         if not hasattr(source, "read"):
# --> 584             source = open(source, "rb")
#     585             close_source = True
# ...
